# %%
import pandas as pd

df = pd.read_csv(
    "../data/processed/model_data.csv"
)

df.head()
# Out:
#         CustomerId  TotalTransactionAmount  AverageTransactionAmount  \
# 0     CustomerId_1                -10000.0             -10000.000000
# 1    CustomerId_10                -10000.0             -10000.000000
# 2  CustomerId_1001                 20000.0               4000.000000
# 3  CustomerId_1002                  4225.0                384.090909
# 4  CustomerId_1003                 20000.0               3333.333333
#
#    TransactionCount  StdTransactionAmount  FraudResult  is_high_risk
# 0                 1              0.000000          0.0             1
# 1                 1              0.000000          0.0             1
# 2                 5           6558.963333          0.0             1
# 3                11            560.498966          0.0             0
# 4                 6           6030.478146          0.0             0

# %%
df["is_high_risk"].value_counts()
# Out:
# is_high_risk
# 0    2315
# 1    1427
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        TotalTransactionAmount  AverageTransactionAmount  TransactionCount  \
# count            3.742000e+03              3.742000e+03       3742.000000
# mean             1.717377e+05              1.571562e+04         25.564404
# std              2.717305e+06              1.676991e+05         96.929602
# min             -1.049000e+08             -4.250000e+05          1.000000
# 25%              4.077438e+03              1.000000e+03          2.000000
# 50%              2.000000e+04              2.583846e+03          7.000000
# 75%              7.996775e+04              4.877614e+03         20.000000
# max              8.345124e+07              8.601821e+06       4091.000000
#
#        StdTransactionAmount  FraudResult  is_high_risk
# count          3.742000e+03  3742.000000   3742.000000
# mean           1.360517e+04     0.005556      0.381347
# std            9.689344e+04     0.064539      0.485782
# min            0.000000e+00     0.000000      0.000000
# ...

# %%
# !python ../src/train.py
# Out:
# 2026/06/02 19:43:58 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2026/06/02 19:43:58 WARNING mlflow.sklearn: Saving scikit-learn models in the pickle or cloudpickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization. The recommended safe alternative is the 'skops' format. For more information, see: https://scikit-learn.org/stable/model_persistence.html
# 2026/06/02 19:44:41 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# ...

# %% [markdown]
# # Model Comparison
#
# Models evaluated:
#
# - Logistic Regression
# - Random Forest
#
# Metrics:
#
# - Accuracy
# - Precision
# - Recall
# - F1 Score
# - ROC-AUC
#
# MLflow was used to track experiments and compare performance.
